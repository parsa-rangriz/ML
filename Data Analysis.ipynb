# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import seaborn as sns

# %% [markdown]
# # Data Importing
#
# First of all, we should import the csv file and see it.

# %%
data = pd.read_csv("/Users/parsarangriz/Downloads/Data_XY.csv")

# %%
data
# Out:
#             1         2         3         4         5         6         7  \
# 0    0.992580  0.992580  0.992580  0.992580  0.992580  0.992580  0.992580
# 1    0.993520  0.993520  0.993520  0.993520  0.993520  0.993520  0.993520
# 2    0.994400  0.994400  0.994400  0.994400  0.994400  0.994400  0.994400
# 3    0.995190  0.995190  0.995190  0.995190  0.995190  0.995190  0.995190
# 4    0.376830  0.376830  0.376830  0.376830  0.376830  0.376830  0.376830
# ..        ...       ...       ...       ...       ...       ...       ...
# 696  0.072026  0.007768  0.000931  0.000117  0.000015  0.000004  0.000015
# 697  0.071922  0.007746  0.000927  0.000116  0.000015  0.000004  0.000015
# 698  0.071818  0.007724  0.000923  0.000116  0.000015  0.000004  0.000015
# 699  0.071715  0.007701  0.000919  0.000115  0.000015  0.000004  0.000015
# 700  0.071612  0.007679  0.000915  0.000114  0.000015  0.000004  0.000015
#
#             8         9        10  ...          4178          4179  \
# ...

# %% [markdown]
# # Data Inspecting
#
# In this part, we want to inspect our data and do some simple analysis

# %%
data.describe()
# Out:
#                 1           2           3           4           5           6  \
# count  701.000000  701.000000  701.000000  701.000000  701.000000  701.000000
# mean     0.272326    0.176532    0.151456    0.142444    0.138810    0.137798
# std      0.276494    0.301180    0.305447    0.306454    0.306735    0.306797
# min      0.071612    0.007679    0.000915    0.000114    0.000015    0.000004
# 25%      0.095676    0.013689    0.002175    0.000363    0.000064    0.000022
# 50%      0.144360    0.031046    0.007407    0.001862    0.000510    0.000250
# 75%      0.297510    0.130990    0.063881    0.033879    0.020761    0.017046
# max      0.997900    0.997890    0.997890    0.997890    0.997890    0.997890
#
#                 7           8           9          10  ...        4178  \
# count  701.000000  701.000000  701.000000  701.000000  ...  701.000000
# mean     0.138810    0.142444    0.151456    0.176532  ...    0.000253
# ...

# %% [markdown]
# ## Correlation
#
# We use this method to demonstrate the correlation of columns.

# %%
corr = data.corr()
corr
# Out:
#              1         2         3         4         5         6         7  \
# 1     1.000000  0.990663  0.978350  0.969956  0.965391  0.963958  0.965391
# 2     0.990663  1.000000  0.997330  0.993755  0.991445  0.990674  0.991445
# 3     0.978350  0.997330  1.000000  0.999234  0.998282  0.997918  0.998282
# 4     0.969956  0.993755  0.999234  1.000000  0.999809  0.999674  0.999809
# 5     0.965391  0.991445  0.998282  0.999809  1.000000  0.999982  1.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 4183  0.006043  0.011708  0.014969  0.016719  0.017570  0.017825  0.017570
# 4184  0.011353  0.015307  0.017430  0.018515  0.019022  0.019170  0.019022
# 4185  0.011353  0.015307  0.017430  0.018515  0.019022  0.019170  0.019022
# 4186  0.023586  0.026957  0.028013  0.028415  0.028569  0.028610  0.028569
# y    -0.812680 -0.734925 -0.691865 -0.669886 -0.659513 -0.656451 -0.659513
#
# ...

# %% [markdown]
# The graph shows that the 1st - ~90th and ~90th - 105th column have corrlation with each other.

# %%
sns.heatmap(corr.iloc[0:91,0:91])
plt.show()

# %%
sns.heatmap(corr.iloc[0:66,0:66])
plt.show()

# %%
sns.heatmap(corr.iloc[0:10,0:10])
plt.show()

# %%
sns.heatmap(corr.iloc[68:78,68:78])
plt.show()

# %%
sns.heatmap(corr.iloc[1:66, 80:90])
plt.show()

# %%
mask = np.triu(np.ones_like(corr.iloc[0:90, 0:90], dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr.iloc[0:90, 0:90], mask=mask, cmap=cmap, vmax=1, vmin = -1, center=0,
            square=True, linewidths=1, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# So, we can conclude that the 91st column devides the data into two sections.

# %% [markdown]
# ## Histogram
# We use this method to demonstrate which values are more repetitive.

# %%
# n, bins, patches = plt.hist(x=data.iloc[:,1], label = 'x1')
n, bins, patches = plt.hist(x=data.iloc[:,20], label = 'x20', width = 0.05)
n, bins, patches = plt.hist(x=data.iloc[:,40], label = 'x40', width = 0.05)
n, bins, patches = plt.hist(x=data.iloc[:,60], label = 'x60', width = 0.05)
n, bins, patches = plt.hist(x=data.iloc[:,60], label = 'x60', width = 0.05)
plt.xlim()
plt.legend()
plt.show()

# %%
n, bins, patches = plt.hist(x=data.iloc[:,69], label = 'x69')
# n, bins, patches = plt.hist(x=data.iloc[:,67], label = 'x67')
# n, bins, patches = plt.hist(x=data.iloc[:,73], label = 'x80')
# n, bins, patches = plt.hist(x=data.iloc[:,75], label = 'x85')
plt.xlim()
plt.legend()
plt.show()

# %%
n, bins, patches = plt.hist(x=data.iloc[:,79], label = 'x79')
n, bins, patches = plt.hist(x=data.iloc[:,80], label = 'x80')
n, bins, patches = plt.hist(x=data.iloc[:,83], label = 'x83')
n, bins, patches = plt.hist(x=data.iloc[:,86], label = 'x86')
plt.xlim()
plt.legend()
plt.show()

# %%
n, bins, patches = plt.hist(x=data.iloc[:,90], label = 'x90')
plt.xlim()
plt.legend()
plt.show()

# %%
n, bins, patches = plt.hist(x=data.iloc[:,100], label = 'x100')
n, bins, patches = plt.hist(x=data.iloc[:,500], label = '500')
n, bins, patches = plt.hist(x=data.iloc[:,1000], label = '1000')
n, bins, patches = plt.hist(x=data.iloc[:,1500], label = 'x1500')
n, bins, patches = plt.hist(x=data.iloc[:,2000], label = 'x2000')
n, bins, patches = plt.hist(x=data.iloc[:,2500], label = 'x2500')
n, bins, patches = plt.hist(x=data.iloc[:,3000], label = 'x3000')
n, bins, patches = plt.hist(x=data.iloc[:,3500], label = 'x3500')
n, bins, patches = plt.hist(x=data.iloc[:,4000], label = 'x4000')
plt.xlim()
plt.legend()
plt.show()

# %% [markdown]
# ## Histogram Plot

# %%
sns.histplot(data.iloc[:,100], kde=True, label = 'x100')
plt.legend()
plt.show()

# %%
sns.histplot(data.iloc[:,90], kde=True, label = 'x90')
plt.legend()
plt.show()

# %% [markdown]
# ## Some Plots

# %%
plt.plot(data.y, data.iloc[:,20], '.', label = 'x20')
plt.plot(data.y, data.iloc[:,40], '.', label = 'x40')
plt.plot(data.y, data.iloc[:,60], '.', label = 'x60')
plt.plot(data.y, data.iloc[:,80], '.', label = 'x80')
plt.legend()
plt.show()

# %%
plt.plot(data.y, data.iloc[:,68], '.', label = 'x68')
plt.plot(data.y, data.iloc[:,72], '.', label = 'x72')
plt.plot(data.y, data.iloc[:,74], '.', label = 'x74')
plt.plot(data.y, data.iloc[:,77], '.', label = 'x77')
plt.legend()
plt.show()

# %%
plt.plot(data.y, data.iloc[:,80], '.', label = 'x20')
plt.plot(data.y, data.iloc[:,82], '.', label = 'x40')
plt.plot(data.y, data.iloc[:,84], '.', label = 'x60')
plt.plot(data.y, data.iloc[:,86], '.', label = 'x80')
plt.legend()
plt.show()

# %%
plt.plot(data.y, data.iloc[:,100], '.', label = 'x100')
plt.plot(data.y, data.iloc[:,500], '.', label = 'x500')
plt.plot(data.y, data.iloc[:,1000], '.', label = 'x1000')
plt.plot(data.y, data.iloc[:,2000], '.', label = 'x2000')
plt.plot(data.y, data.iloc[:,3000], '.', label = 'x3000')
plt.plot(data.y, data.iloc[:,4000], '.', label = 'x4000')
plt.legend()
plt.show()

# %% [markdown]
# # Regression

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors
n_neighbors = 15

X_data = [data.y, data.x91, data.x92]
X = np.zeros((len(X_data[0]), len(X_data)))
for i in range(len(X_data)):
    for j in range(len(X_data[i])):
        X[j][i] = X_data[i][j]

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
regr_1 = DecisionTreeRegressor(max_depth=5)
regr_2 = DecisionTreeRegressor(max_depth=5)
X0 = np.array([X[:, 0]]).T
X1 = np.array([X[:, 1]]).T
X2 = np.array([X[:, 2]]).T
regr_1.fit(X0, X1)
regr_2.fit(X0, X2)
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)
plt.figure()
plt.scatter(X0, X1, s=20, label="x91")
plt.scatter(X0, X2, s=20, label="x92")
plt.plot(X_test, y_1, label="max_depth=5", c = 'yellow')
plt.plot(X_test, y_2, label="max_depth=5", c = 'blue')
plt.legend()
plt.show()

# %% [markdown]
# ## Nearest Neighbors

# %%
from sklearn import neighbors
T = np.linspace(0, 5, 500)[:, np.newaxis]
n_neighbors = 5
knn = neighbors.KNeighborsRegressor(n_neighbors, weights = 'uniform')
y_ = knn.fit(X0, X1).predict(T)
y__ = knn.fit(X0, X2).predict(T)
plt.scatter(X0, X1, color='darkorange', label='data')
plt.scatter(X0, X2, color='blue', label='data')
plt.plot(T, y_, color='navy', label='prediction')
plt.plot(T, y__, color='orange', label='prediction')
plt.legend()                                                   
plt.show()
